# %% [markdown]
# <a href="https://colab.research.google.com/github/WesleySouza13/Redes-Neurais-e-Deep-Learning-/blob/main/Alzheimer's_Disease_Dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/alzheimers_disease_data.csv')

# %%
df #Diagnosis é a nossa coluna alvo
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
df.isnull().sum()
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# ...

# %%
df.dtypes
# Out:
# PatientID                      int64
# Age                            int64
# Gender                         int64
# Ethnicity                      int64
# EducationLevel                 int64
# BMI                          float64
# Smoking                        int64
# AlcoholConsumption           float64
# PhysicalActivity             float64
# DietQuality                  float64
# SleepQuality                 float64
# FamilyHistoryAlzheimers        int64
# CardiovascularDisease          int64
# Diabetes                       int64
# Depression                     int64
# HeadInjury                     int64
# Hypertension                   int64
# SystolicBP                     int64
# DiastolicBP                    int64
# CholesterolTotal             float64
# CholesterolLDL               float64
# CholesterolHDL               float64
# CholesterolTriglycerides     float64
# MMSE                         float64
# FunctionalAssessment         float64
# ...

# %%
df['DoctorInCharge'].unique()
# Out:
# array(['XXXConfid'], dtype=object)

# %%
graf1 = df['Age']
plt.figure(figsize=(20,7))
plt.bar(graf1.index, graf1.values)
plt.show()

# %%
df['DoctorInCharge']=df['DoctorInCharge'].replace({'XXXConfid':0})

# %%
#criação de x e y (analise e alvo)
x = df.drop('Diagnosis', axis=1)
y = df['Diagnosis']

# %%
x
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2144    1
# 2145    1
# 2146    1
# 2147    1
# 2148    0
# Name: Diagnosis, Length: 2149, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y,test_size = 0.3)

# %%
x_treino.shape, x_teste.shape
# Out:
# ((1504, 34), (645, 34))

# %%
y_treino.shape, y_teste.shape
# Out:
# ((1504,), (645,))

# %%
from sklearn.neural_network import MLPClassifier

# %%
(34+1)/2
# Out:
# 17.5

# %%
rede_neural_Alzheimer = MLPClassifier(max_iter=1500, verbose=True, tol=0.000100, solver ='adam', activation = 'relu', hidden_layer_sizes=(7,7))
rede_neural_Alzheimer.fit(x_treino, y_treino)
# Out:
# Iteration 1, loss = 23.34210575
# Iteration 2, loss = 23.34210569
# Iteration 3, loss = 23.34210562
# Iteration 4, loss = 23.34210555
# Iteration 5, loss = 23.34210548
# Iteration 6, loss = 23.34210542
# Iteration 7, loss = 23.34210536
# Iteration 8, loss = 14.55473932
# Iteration 9, loss = 12.69778310
# Iteration 10, loss = 12.48368478
# Iteration 11, loss = 7.52836496
# Iteration 12, loss = 7.39144080
# Iteration 13, loss = 6.31579332
# Iteration 14, loss = 5.39310225
# Iteration 15, loss = 5.00180770
# Iteration 16, loss = 4.89377142
# Iteration 17, loss = 4.89778030
# Iteration 18, loss = 4.80184056
# Iteration 19, loss = 4.73689773
# Iteration 20, loss = 4.70381368
# Iteration 21, loss = 4.67539551
# Iteration 22, loss = 4.64730693
# Iteration 23, loss = 4.59995148
# Iteration 24, loss = 4.59472213
# Iteration 25, loss = 4.55616048
# Iteration 26, loss = 4.49328023
# Iteration 27, loss = 4.45741975
# Iteration 28, loss = 4.43049051
# Iteration 29, loss = 4.39553155
# ...

# %%
previsoes = rede_neural_Alzheimer.predict(x_teste)
acuracia = rede_neural_Alzheimer.score(x_teste, y_teste)
print(acuracia)
# Out:
# 0.7891472868217054
